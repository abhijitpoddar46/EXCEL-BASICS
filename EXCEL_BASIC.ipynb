# %% [markdown]
# # EXCEL BASICS

# %% [markdown]
# 1. xplain the difference between Relative , Absolute and Mixed Cell Referencing.

# %% [markdown]
# ->THE ROW AND/OR COLUMN REFERENCES CHANGE(RELATIVE), REMAIN CONSTANT(ABSOLUTE),COMBINATION OF BOTH (MIXED).

# %% [markdown]
# 2.rite a formula to calculate the total sales of Car and Bicyle only only

# %% [markdown]
# -> SUM(CAR,BICYCLE)

# %% [markdown]
# 3.Using the data below, write a formula to calculate the average sales of items priced above 100 but less than
# 300:

# %% [markdown]
# -> AVERAGEIFS(C:C,B:B,">100",B:B,"<300")

# %% [markdown]
# 4.Count how many customer names are recorded.

# %% [markdown]
# -> 50

# %% [markdown]
# 5.Calculate the Total Sales for each row using a formula.

# %% [markdown]
# ->16543

# %% [markdown]
# 6.Calculate the total sales of Notebooks in the North region only.

# %% [markdown]
# ->2900
